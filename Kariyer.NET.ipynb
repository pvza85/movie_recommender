# %%
import pandas as pd

# %%
xlsxfile_candidate = pd.ExcelFile('aday.xlsx')

# %%
xlsxfile_job = pd.ExcelFile('ilan.xlsx')

# %%
df_candidate = xlsxfile_candidate.parse('Sayfa1')

# %%
df_job = pd.merge(xlsxfile_job.parse('Sayfa1'), xlsxfile_job.parse('Sayfa2'), 
                  left_on='ilan no', right_on='ClientJobRefNo')

# %%
ClientJobRefNo

# %%
df_job
# Out:
#       ilan no                                         firma ismi  \
# 0   210215-YU                                      Emin Otomotiv
# 1      Bİ001Y                Binova Bilişim & Innotech Teknoloji
# 2   KN-YU-009                                        Kariyer.net
# 3     CRN-013                                             Cronom
# 4   GZYZUZM02                                         Gizli İlan
# 5  SA-Y-UZIMN  Saldem Bilişim Teknolojileri Enr. İnş. Yazılım Te
# 6  TTS-YZLMUZ                                              Tetaş
# 7      YAZ100                        KURS BİLİŞİM ANONİM ŞİRKETİ
# 8  yz23022015                         Techlife Bilişim Çözümleri
# 9       YZL01             DESMER GÜVENLİK HİZMETLERİ TİCARET AŞ.
#
#                  Ilan PozisyonIsmi  yayıntarihi     PozisyonAdi  \
# 0  Yazılım Uzmanı (Anadolu Yakası)   20150609.0  Yazılım Uzmanı
# 1   Junior / Senior Yazılım Uzmanı   20151204.0  Yazılım Uzmanı
# ...
